# %%
import os
import json
import pandas as pd
import altair as alt
import difflib
import re

# %%
def instruction_finetune_dataset(base_path):
    """
    Reconfigure the dataset to combine information from each subfolder
    into a single text file for each main folder.

    :param base_path: Path to the dataset's root directory.
    :param output_path: Path to save the reconfigured files.
    """
    processed_data = []
    # Iterate through each folder in the base path
    for main_folder in os.listdir(base_path):
        main_folder_path = os.path.join(base_path, main_folder)
        print(main_folder_path)
        print("\n\n")
        if not os.path.isdir(main_folder_path):
            continue

        # output_file = os.path.join(output_path, f"{main_folder}_bug.txt")
        
        # with open(output_file, 'w', encoding='utf-8') as outfile:
        # Iterate through subfolders
        for subfolder in sorted(os.listdir(main_folder_path)):
            
            subfolder_path = os.path.join(main_folder_path, subfolder)
            print(subfolder_path)
            print("\n\n")
            if not os.path.isdir(subfolder_path):
                continue

            # Define file paths
            method_before_path = os.path.join(subfolder_path, 'method_before.txt')
            method_after_path = os.path.join(subfolder_path, 'method_after.txt')
            bug_json_path = os.path.join(subfolder_path, 'bug.json')

            # Read content from files if they exist
            method_before = read_file(method_before_path)
            method_after = read_file(method_after_path)
            bug_info = read_json(bug_json_path)
            bug_info = {k:v for k, v in bug_info.items() if k in ['bug_type', 'qualifier']}
            # Write to the output file
            # input_text = f"""
            #             ---
            #             Method Level Code containing bug:\n
            #             {method_before}
            #             \n\n
            #             Error Information:\n
            #             {str(bug_info)}
            #             ---"""
            # output_text = method_after
            
            processed_data.append({
                "BuggyCode": method_before,
                "BugInfo": bug_info,
                "FixedCode": method_after
            })

    return processed_data

def read_file(file_path):
    """Read the content of a file if it exists."""
    if os.path.exists(file_path):
        with open(file_path, 'r', encoding='utf-8') as file:
            return file.read().strip()
    return "File not found."

def read_json(file_path):
    """Read and parse a JSON file if it exists."""
    if os.path.exists(file_path):
        with open(file_path, 'r', encoding='utf-8') as file:
            return json.load(file)
    return {"error": "File not found."}

base_path = "InferredBugs/inferredbugs/java" 
output_path = "Processed_InferredBugs_InstructionFineTune"
processed_data = instruction_finetune_dataset(base_path)
# Out:
# InferredBugs/inferredbugs/java/shadowsocks-java
#
#
#
# InferredBugs/inferredbugs/java/shadowsocks-java/1
#
#
#
# InferredBugs/inferredbugs/java/shadowsocks-java/2
#
#
#
# InferredBugs/inferredbugs/java/shadowsocks-java/3
#
#
#
# InferredBugs/inferredbugs/java/find-sec-bugs
#
#
#
# InferredBugs/inferredbugs/java/find-sec-bugs/1
#
#
#
# InferredBugs/inferredbugs/java/find-sec-bugs/2
#
#
#
# InferredBugs/inferredbugs/java/find-sec-bugs/3
#
#
#
# InferredBugs/inferredbugs/java/find-sec-bugs/4
#
#
#
# InferredBugs/inferredbugs/java/find-sec-bugs/5
#
#
#
# InferredBugs/inferredbugs/java/find-sec-bugs/6
#
#
#
# InferredBugs/inferredbugs/java/find-sec-bugs/7
#
#
#
# InferredBugs/inferredbugs/java/find-sec-bugs/8
#
#
#
# InferredBugs/inferredbugs/java/jansi
#
#
#
# InferredBugs/inferredbugs/java/jansi/1
#
#
#
# InferredBugs/inferredbugs/java/ShiroJwt
#
#
#
# InferredBugs/inferredbugs/java/ShiroJwt/1
#
#
#
# InferredBugs/inferredbugs/java/ShiroJwt/2
#
#
#
# InferredBugs/inferredbugs/java/ShiroJwt/3
#
#
#
# InferredBugs/inferredbugs/java/ShiroJwt/4
#
#
#
# InferredBugs/inferredbugs/java/bigqueue
#
#
#
# InferredBugs/inferredbugs/java/bigqueue/1
#
#
#
# InferredBugs/inferredbugs/java/bigqueue/2
#
#
#
# InferredBugs/inferredbugs/java/LWC
#
#
#
# InferredBugs/inferredbugs/java/LWC/1
#
#
#
# InferredBugs/inferredbugs/java/LWC/2
#
#
#
# InferredBugs/inferredbugs/java/LWC/3
#
#
#
# InferredBugs/inferredbugs/java/LWC/4
#
#
#
# InferredBugs/inferredbugs/java/LWC/5
#
#
#
# InferredBugs/inferredbugs/java/LWC/6
#
#
#
# InferredBugs/inferredbugs/java/LWC/7
#
#
#
# InferredBugs/inferredbugs/java/LWC/8
#
#
#
# InferredBugs/inferredbugs/java/LWC/9
#
#
#
# InferredBugs/inferredbugs/java/antares
#
#
#
# InferredBugs/inferredbugs/java/antares/1
#
#
#
# InferredBugs/inferredbugs/java/antares/2
#
#
#
# InferredBugs/inferredbugs/java/testcontainers-spring-boot
#
#
#
# InferredBugs/inferredbugs/java/testcontainers-spring-boot/1
#
#
#
# InferredBugs/inferredbugs/java/testcontainers-spring-boot/2
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/1
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/10
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/11
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/12
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/13
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/14
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/15
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/16
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/17
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/18
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/19
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/2
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/20
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/21
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/22
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/23
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/24
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/25
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/26
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/27
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/28
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/29
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/3
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/30
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/31
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/32
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/33
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/34
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/35
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/36
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/37
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/38
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/39
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/4
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/40
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/41
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/42
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/43
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/44
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/45
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/46
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/47
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/48
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/49
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/5
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/50
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/51
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/52
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/53
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/54
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/55
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/56
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/57
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/58
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/59
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/6
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/60
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/61
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/62
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/63
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/64
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/65
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/66
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/67
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/68
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/69
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/7
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/70
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/71
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/72
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/73
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/74
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/75
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/76
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/77
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/78
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/79
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/8
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/80
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/81
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/82
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/83
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/84
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/85
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/86
#
#
#
# InferredBugs/inferredbugs/java/webdrivermanager/9
#
#
#
# InferredBugs/inferredbugs/java/Java-Thread-Affinity
#
#
#
# InferredBugs/inferredbugs/java/Java-Thread-Affinity/1
#
#
#
# InferredBugs/inferredbugs/java/Java-Thread-Affinity/2
#
#
#
# InferredBugs/inferredbugs/java/Java-Thread-Affinity/3
#
#
#
# InferredBugs/inferredbugs/java/Java-Thread-Affinity/4
#
#
#
# InferredBugs/inferredbugs/java/Java-Thread-Affinity/5
#
#
#
# InferredBugs/inferredbugs/java/Java-Thread-Affinity/6
#
#
#
# InferredBugs/inferredbugs/java/tinkerpop
#
#
#
# InferredBugs/inferredbugs/java/tinkerpop/1
#
#
#
# InferredBugs/inferredbugs/java/tinkerpop/2
#
#
#
# InferredBugs/inferredbugs/java/tinkerpop/3
#
#
#
# InferredBugs/inferredbugs/java/tinkerpop/4
#
#
#
# InferredBugs/inferredbugs/java/tinkerpop/5
#
#
#
# InferredBugs/inferredbugs/java/farm
#
#
#
# InferredBugs/inferredbugs/java/farm/1
#
#
#
# InferredBugs/inferredbugs/java/farm/10
#
#
#
# InferredBugs/inferredbugs/java/farm/100
#
#
#
# InferredBugs/inferredbugs/java/farm/101
#
#
#
# InferredBugs/inferredbugs/java/farm/102
#
#
#
# InferredBugs/inferredbugs/java/farm/103
#
#
#
# InferredBugs/inferredbugs/java/farm/104
#
#
#
# InferredBugs/inferredbugs/java/farm/105
#
#
#
# InferredBugs/inferredbugs/java/farm/106
#
#
#
# InferredBugs/inferredbugs/java/farm/107
#
#
#
# InferredBugs/inferredbugs/java/farm/108
#
#
#
# InferredBugs/inferredbugs/java/farm/109
#
#
#
# InferredBugs/inferredbugs/java/farm/11
#
#
#
# InferredBugs/inferredbugs/java/farm/110
#
#
#
# InferredBugs/inferredbugs/java/farm/111
#
#
#
# InferredBugs/inferredbugs/java/farm/112
#
#
#
# InferredBugs/inferredbugs/java/farm/113
#
#
#
# InferredBugs/inferredbugs/java/farm/114
#
#
#
# InferredBugs/inferredbugs/java/farm/115
#
#
#
# InferredBugs/inferredbugs/java/farm/116
#
#
#
# InferredBugs/inferredbugs/java/farm/117
#
#
#
# InferredBugs/inferredbugs/java/farm/118
#
#
#
# InferredBugs/inferredbugs/java/farm/119
#
#
#
# InferredBugs/inferredbugs/java/farm/12
#
#
#
# InferredBugs/inferredbugs/java/farm/120
#
#
#
# InferredBugs/inferredbugs/java/farm/121
#
#
#
# InferredBugs/inferredbugs/java/farm/122
#
#
#
# InferredBugs/inferredbugs/java/farm/123
#
#
#
# InferredBugs/inferredbugs/java/farm/124
#
#
#
# InferredBugs/inferredbugs/java/farm/125
#
#
#
# InferredBugs/inferredbugs/java/farm/126
#
#
#
# InferredBugs/inferredbugs/java/farm/127
#
#
#
# InferredBugs/inferredbugs/java/farm/128
#
#
#
# InferredBugs/inferredbugs/java/farm/129
#
#
#
# InferredBugs/inferredbugs/java/farm/13
#
#
#
# InferredBugs/inferredbugs/java/farm/130
#
#
#
# InferredBugs/inferredbugs/java/farm/131
#
#
#
# InferredBugs/inferredbugs/java/farm/132
#
#
#
# InferredBugs/inferredbugs/java/farm/133
#
#
#
# InferredBugs/inferredbugs/java/farm/134
#
#
#
# InferredBugs/inferredbugs/java/farm/135
#
#
#
# InferredBugs/inferredbugs/java/farm/136
#
#
#
# InferredBugs/inferredbugs/java/farm/137
#
#
#
# InferredBugs/inferredbugs/java/farm/138
#
#
#
# InferredBugs/inferredbugs/java/farm/139
#
#
#
# InferredBugs/inferredbugs/java/farm/14
#
#
#
# InferredBugs/inferredbugs/java/farm/140
#
#
#
# InferredBugs/inferredbugs/java/farm/141
#
#
#
# InferredBugs/inferredbugs/java/farm/15
#
#
#
# InferredBugs/inferredbugs/java/farm/16
#
#
#
# InferredBugs/inferredbugs/java/farm/17
#
#
#
# InferredBugs/inferredbugs/java/farm/18
#
#
#
# InferredBugs/inferredbugs/java/farm/19
#
#
#
# InferredBugs/inferredbugs/java/farm/2
#
#
#
# InferredBugs/inferredbugs/java/farm/20
#
#
#
# InferredBugs/inferredbugs/java/farm/21
#
#
#
# InferredBugs/inferredbugs/java/farm/22
#
#
#
# InferredBugs/inferredbugs/java/farm/23
#
#
#
# InferredBugs/inferredbugs/java/farm/24
#
#
#
# InferredBugs/inferredbugs/java/farm/25
#
#
#
# InferredBugs/inferredbugs/java/farm/26
#
#
#
# InferredBugs/inferredbugs/java/farm/27
#
#
#
# InferredBugs/inferredbugs/java/farm/28
#
#
#
# InferredBugs/inferredbugs/java/farm/29
#
#
#
# InferredBugs/inferredbugs/java/farm/3
#
#
#
# InferredBugs/inferredbugs/java/farm/30
#
#
#
# InferredBugs/inferredbugs/java/farm/31
#
#
#
# InferredBugs/inferredbugs/java/farm/32
#
#
#
# InferredBugs/inferredbugs/java/farm/33
#
#
#
# InferredBugs/inferredbugs/java/farm/34
#
#
#
# InferredBugs/inferredbugs/java/farm/35
#
#
#
# InferredBugs/inferredbugs/java/farm/36
#
#
#
# InferredBugs/inferredbugs/java/farm/37
#
#
#
# InferredBugs/inferredbugs/java/farm/38
#
#
#
# InferredBugs/inferredbugs/java/farm/39
#
#
#
# InferredBugs/inferredbugs/java/farm/4
#
#
#
# InferredBugs/inferredbugs/java/farm/40
#
#
#
# InferredBugs/inferredbugs/java/farm/41
#
#
#
# InferredBugs/inferredbugs/java/farm/42
#
#
#
# InferredBugs/inferredbugs/java/farm/43
#
#
#
# InferredBugs/inferredbugs/java/farm/44
#
#
#
# InferredBugs/inferredbugs/java/farm/45
#
#
#
# InferredBugs/inferredbugs/java/farm/46
#
#
#
# InferredBugs/inferredbugs/java/farm/47
#
#
#
# InferredBugs/inferredbugs/java/farm/48
#
#
#
# InferredBugs/inferredbugs/java/farm/49
#
#
#
# InferredBugs/inferredbugs/java/farm/5
#
#
#
# InferredBugs/inferredbugs/java/farm/50
#
#
#
# InferredBugs/inferredbugs/java/farm/51
#
#
#
# InferredBugs/inferredbugs/java/farm/52
#
#
#
# InferredBugs/inferredbugs/java/farm/53
#
#
#
# InferredBugs/inferredbugs/java/farm/54
#
#
#
# InferredBugs/inferredbugs/java/farm/55
#
#
#
# InferredBugs/inferredbugs/java/farm/56
#
#
#
# InferredBugs/inferredbugs/java/farm/57
#
#
#
# InferredBugs/inferredbugs/java/farm/58
#
#
#
# InferredBugs/inferredbugs/java/farm/59
#
#
#
# InferredBugs/inferredbugs/java/farm/6
#
#
#
# InferredBugs/inferredbugs/java/farm/60
#
#
#
# InferredBugs/inferredbugs/java/farm/61
#
#
#
# InferredBugs/inferredbugs/java/farm/62
#
#
#
# InferredBugs/inferredbugs/java/farm/63
#
#
#
# InferredBugs/inferredbugs/java/farm/64
#
#
#
# InferredBugs/inferredbugs/java/farm/65
#
#
#
# InferredBugs/inferredbugs/java/farm/66
#
#
#
# InferredBugs/inferredbugs/java/farm/67
#
#
#
# InferredBugs/inferredbugs/java/farm/68
#
#
#
# InferredBugs/inferredbugs/java/farm/69
#
#
#
# InferredBugs/inferredbugs/java/farm/7
#
#
#
# InferredBugs/inferredbugs/java/farm/70
#
#
#
# InferredBugs/inferredbugs/java/farm/71
#
#
#
# InferredBugs/inferredbugs/java/farm/72
#
#
#
# InferredBugs/inferredbugs/java/farm/73
#
#
#
# InferredBugs/inferredbugs/java/farm/74
#
#
#
# InferredBugs/inferredbugs/java/farm/75
#
#
#
# InferredBugs/inferredbugs/java/farm/76
#
#
#
# InferredBugs/inferredbugs/java/farm/77
#
#
#
# InferredBugs/inferredbugs/java/farm/78
#
#
#
# InferredBugs/inferredbugs/java/farm/79
#
#
#
# InferredBugs/inferredbugs/java/farm/8
#
#
#
# InferredBugs/inferredbugs/java/farm/80
#
#
#
# InferredBugs/inferredbugs/java/farm/81
#
#
#
# InferredBugs/inferredbugs/java/farm/82
#
#
#
# InferredBugs/inferredbugs/java/farm/83
#
#
#
# InferredBugs/inferredbugs/java/farm/84
#
#
#
# InferredBugs/inferredbugs/java/farm/85
#
#
#
# InferredBugs/inferredbugs/java/farm/86
#
#
#
# InferredBugs/inferredbugs/java/farm/87
#
#
#
# InferredBugs/inferredbugs/java/farm/88
#
#
#
# InferredBugs/inferredbugs/java/farm/89
#
#
#
# InferredBugs/inferredbugs/java/farm/9
#
#
#
# InferredBugs/inferredbugs/java/farm/90
#
#
#
# InferredBugs/inferredbugs/java/farm/91
#
#
#
# InferredBugs/inferredbugs/java/farm/92
#
#
#
# InferredBugs/inferredbugs/java/farm/93
#
#
#
# InferredBugs/inferredbugs/java/farm/94
#
#
#
# InferredBugs/inferredbugs/java/farm/95
#
#
#
# InferredBugs/inferredbugs/java/farm/96
#
#
#
# InferredBugs/inferredbugs/java/farm/97
#
#
#
# InferredBugs/inferredbugs/java/farm/98
#
#
#
# InferredBugs/inferredbugs/java/farm/99
#
#
#
# InferredBugs/inferredbugs/java/hank
#
#
#
# InferredBugs/inferredbugs/java/hank/1
#
#
#
# InferredBugs/inferredbugs/java/hank/10
#
#
#
# InferredBugs/inferredbugs/java/hank/11
#
#
#
# InferredBugs/inferredbugs/java/hank/12
#
#
#
# InferredBugs/inferredbugs/java/hank/13
#
#
#
# InferredBugs/inferredbugs/java/hank/14
#
#
#
# InferredBugs/inferredbugs/java/hank/15
#
#
#
# InferredBugs/inferredbugs/java/hank/16
#
#
#
# InferredBugs/inferredbugs/java/hank/17
#
#
#
# InferredBugs/inferredbugs/java/hank/18
#
#
#
# InferredBugs/inferredbugs/java/hank/19
#
#
#
# InferredBugs/inferredbugs/java/hank/2
#
#
#
# InferredBugs/inferredbugs/java/hank/20
#
#
#
# InferredBugs/inferredbugs/java/hank/21
#
#
#
# InferredBugs/inferredbugs/java/hank/22
#
#
#
# InferredBugs/inferredbugs/java/hank/23
#
#
#
# InferredBugs/inferredbugs/java/hank/24
#
#
#
# InferredBugs/inferredbugs/java/hank/25
#
#
#
# InferredBugs/inferredbugs/java/hank/26
#
#
#
# InferredBugs/inferredbugs/java/hank/27
#
#
#
# InferredBugs/inferredbugs/java/hank/28
#
#
#
# InferredBugs/inferredbugs/java/hank/29
#
#
#
# InferredBugs/inferredbugs/java/hank/3
#
#
#
# InferredBugs/inferredbugs/java/hank/30
#
#
#
# InferredBugs/inferredbugs/java/hank/31
#
#
#
# InferredBugs/inferredbugs/java/hank/32
#
#
#
# InferredBugs/inferredbugs/java/hank/33
#
#
#
# InferredBugs/inferredbugs/java/hank/34
#
#
#
# InferredBugs/inferredbugs/java/hank/35
#
#
#
# InferredBugs/inferredbugs/java/hank/36
#
#
#
# InferredBugs/inferredbugs/java/hank/37
#
#
#
# InferredBugs/inferredbugs/java/hank/38
#
#
#
# InferredBugs/inferredbugs/java/hank/39
#
#
#
# InferredBugs/inferredbugs/java/hank/4
#
#
#
# InferredBugs/inferredbugs/java/hank/40
#
#
#
# InferredBugs/inferredbugs/java/hank/41
#
#
#
# InferredBugs/inferredbugs/java/hank/42
#
#
#
# InferredBugs/inferredbugs/java/hank/43
#
#
#
# InferredBugs/inferredbugs/java/hank/44
#
#
#
# InferredBugs/inferredbugs/java/hank/45
#
#
#
# InferredBugs/inferredbugs/java/hank/46
#
#
#
# InferredBugs/inferredbugs/java/hank/47
#
#
#
# InferredBugs/inferredbugs/java/hank/48
#
#
#
# InferredBugs/inferredbugs/java/hank/49
#
#
#
# InferredBugs/inferredbugs/java/hank/5
#
#
#
# InferredBugs/inferredbugs/java/hank/50
#
#
#
# InferredBugs/inferredbugs/java/hank/51
#
#
#
# InferredBugs/inferredbugs/java/hank/52
#
#
#
# InferredBugs/inferredbugs/java/hank/53
#
#
#
# InferredBugs/inferredbugs/java/hank/54
#
#
#
# InferredBugs/inferredbugs/java/hank/55
#
#
#
# InferredBugs/inferredbugs/java/hank/56
#
#
#
# InferredBugs/inferredbugs/java/hank/57
#
#
#
# InferredBugs/inferredbugs/java/hank/58
#
#
#
# InferredBugs/inferredbugs/java/hank/59
#
#
#
# InferredBugs/inferredbugs/java/hank/6
#
#
#
# InferredBugs/inferredbugs/java/hank/7
#
#
#
# InferredBugs/inferredbugs/java/hank/8
#
#
#
# InferredBugs/inferredbugs/java/hank/9
#
#
#
# InferredBugs/inferredbugs/java/kafka-eagle
#
#
#
# InferredBugs/inferredbugs/java/kafka-eagle/1
#
#
#
# InferredBugs/inferredbugs/java/kafka-eagle/2
#
#
#
# InferredBugs/inferredbugs/java/kafka-eagle/3
#
#
#
# InferredBugs/inferredbugs/java/kafka-eagle/4
#
#
#
# InferredBugs/inferredbugs/java/kafka-eagle/5
#
#
#
# InferredBugs/inferredbugs/java/kafka-eagle/6
#
#
#
# InferredBugs/inferredbugs/java/kafka-eagle/7
#
#
#
# InferredBugs/inferredbugs/java/kafka-eagle/8
#
#
#
# InferredBugs/inferredbugs/java/jsr354-ri
#
#
#
# InferredBugs/inferredbugs/java/jsr354-ri/1
#
#
#
# InferredBugs/inferredbugs/java/jsr354-ri/2
#
#
#
# InferredBugs/inferredbugs/java/jsr354-ri/3
#
#
#
# InferredBugs/inferredbugs/java/jsr354-ri/4
#
#
#
# InferredBugs/inferredbugs/java/jmxtrans-agent
#
#
#
# InferredBugs/inferredbugs/java/jmxtrans-agent/1
#
#
#
# InferredBugs/inferredbugs/java/FastDFS_Client
#
#
#
# InferredBugs/inferredbugs/java/FastDFS_Client/1
#
#
#
# InferredBugs/inferredbugs/java/FastDFS_Client/10
#
#
#
# InferredBugs/inferredbugs/java/FastDFS_Client/2
#
#
#
# InferredBugs/inferredbugs/java/FastDFS_Client/3
#
#
#
# InferredBugs/inferredbugs/java/FastDFS_Client/4
#
#
#
# InferredBugs/inferredbugs/java/FastDFS_Client/5
#
#
#
# InferredBugs/inferredbugs/java/FastDFS_Client/6
#
#
#
# InferredBugs/inferredbugs/java/FastDFS_Client/7
#
#
#
# InferredBugs/inferredbugs/java/FastDFS_Client/8
#
#
#
# InferredBugs/inferredbugs/java/FastDFS_Client/9
#
#
#
# InferredBugs/inferredbugs/java/shopizer
#
#
#
# InferredBugs/inferredbugs/java/shopizer/1
#
#
#
# InferredBugs/inferredbugs/java/shopizer/2
#
#
#
# InferredBugs/inferredbugs/java/shopizer/3
#
#
#
# InferredBugs/inferredbugs/java/shopizer/4
#
#
#
# InferredBugs/inferredbugs/java/shopizer/5
#
#
#
# InferredBugs/inferredbugs/java/shopizer/6
#
#
#
# InferredBugs/inferredbugs/java/shopizer/7
#
#
#
# InferredBugs/inferredbugs/java/shopizer/8
#
#
#
# InferredBugs/inferredbugs/java/clue
#
#
#
# InferredBugs/inferredbugs/java/clue/1
#
#
#
# InferredBugs/inferredbugs/java/clue/2
#
#
#
# InferredBugs/inferredbugs/java/clue/3
#
#
#
# InferredBugs/inferredbugs/java/clue/4
#
#
#
# InferredBugs/inferredbugs/java/clue/5
#
#
#
# InferredBugs/inferredbugs/java/firefly
#
#
#
# InferredBugs/inferredbugs/java/firefly/1
#
#
#
# InferredBugs/inferredbugs/java/firefly/10
#
#
#
# InferredBugs/inferredbugs/java/firefly/11
#
#
#
# InferredBugs/inferredbugs/java/firefly/12
#
#
#
# InferredBugs/inferredbugs/java/firefly/13
#
#
#
# InferredBugs/inferredbugs/java/firefly/14
#
#
#
# InferredBugs/inferredbugs/java/firefly/15
#
#
#
# InferredBugs/inferredbugs/java/firefly/16
#
#
#
# InferredBugs/inferredbugs/java/firefly/17
#
#
#
# InferredBugs/inferredbugs/java/firefly/18
#
#
#
# InferredBugs/inferredbugs/java/firefly/19
#
#
#
# InferredBugs/inferredbugs/java/firefly/2
#
#
#
# InferredBugs/inferredbugs/java/firefly/20
#
#
#
# InferredBugs/inferredbugs/java/firefly/21
#
#
#
# InferredBugs/inferredbugs/java/firefly/22
#
#
#
# InferredBugs/inferredbugs/java/firefly/23
#
#
#
# InferredBugs/inferredbugs/java/firefly/24
#
#
#
# InferredBugs/inferredbugs/java/firefly/25
#
#
#
# InferredBugs/inferredbugs/java/firefly/26
#
#
#
# InferredBugs/inferredbugs/java/firefly/27
#
#
#
# InferredBugs/inferredbugs/java/firefly/28
#
#
#
# InferredBugs/inferredbugs/java/firefly/29
#
#
#
# InferredBugs/inferredbugs/java/firefly/3
#
#
#
# InferredBugs/inferredbugs/java/firefly/30
#
#
#
# InferredBugs/inferredbugs/java/firefly/31
#
#
#
# InferredBugs/inferredbugs/java/firefly/32
#
#
#
# InferredBugs/inferredbugs/java/firefly/33
#
#
#
# InferredBugs/inferredbugs/java/firefly/34
#
#
#
# InferredBugs/inferredbugs/java/firefly/4
#
#
#
# InferredBugs/inferredbugs/java/firefly/5
#
#
#
# InferredBugs/inferredbugs/java/firefly/6
#
#
#
# InferredBugs/inferredbugs/java/firefly/7
#
#
#
# InferredBugs/inferredbugs/java/firefly/8
#
#
#
# InferredBugs/inferredbugs/java/firefly/9
#
#
#
# InferredBugs/inferredbugs/java/hibernate-tools
#
#
#
# InferredBugs/inferredbugs/java/hibernate-tools/1
#
#
#
# InferredBugs/inferredbugs/java/hibernate-tools/2
#
#
#
# InferredBugs/inferredbugs/java/hibernate-tools/3
#
#
#
# InferredBugs/inferredbugs/java/hibernate-tools/4
#
#
#
# InferredBugs/inferredbugs/java/weixin-popular
#
#
#
# InferredBugs/inferredbugs/java/weixin-popular/1
#
#
#
# InferredBugs/inferredbugs/java/tracer
#
#
#
# InferredBugs/inferredbugs/java/tracer/1
#
#
#
# InferredBugs/inferredbugs/java/docker-plugin
#
#
#
# InferredBugs/inferredbugs/java/docker-plugin/1
#
#
#
# InferredBugs/inferredbugs/java/docker-plugin/2
#
#
#
# InferredBugs/inferredbugs/java/docker-plugin/3
#
#
#
# InferredBugs/inferredbugs/java/docker-plugin/4
#
#
#
# InferredBugs/inferredbugs/java/docker-plugin/5
#
#
#
# InferredBugs/inferredbugs/java/mblog
#
#
#
# InferredBugs/inferredbugs/java/mblog/1
#
#
#
# InferredBugs/inferredbugs/java/mblog/2
#
#
#
# InferredBugs/inferredbugs/java/Spout
#
#
#
# InferredBugs/inferredbugs/java/Spout/1
#
#
#
# InferredBugs/inferredbugs/java/Spout/2
#
#
#
# InferredBugs/inferredbugs/java/Spout/3
#
#
#
# InferredBugs/inferredbugs/java/Spout/4
#
#
#
# InferredBugs/inferredbugs/java/Moss
#
#
#
# InferredBugs/inferredbugs/java/Moss/1
#
#
#
# InferredBugs/inferredbugs/java/proguard-maven-plugin
#
#
#
# InferredBugs/inferredbugs/java/proguard-maven-plugin/1
#
#
#
# InferredBugs/inferredbugs/java/azure-maven-plugins
#
#
#
# InferredBugs/inferredbugs/java/azure-maven-plugins/1
#
#
#
# InferredBugs/inferredbugs/java/azure-maven-plugins/2
#
#
#
# InferredBugs/inferredbugs/java/azure-maven-plugins/3
#
#
#
# InferredBugs/inferredbugs/java/azure-maven-plugins/4
#
#
#
# InferredBugs/inferredbugs/java/commons-codec
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/1
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/10
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/11
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/12
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/13
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/14
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/15
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/16
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/17
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/18
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/19
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/2
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/20
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/21
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/22
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/23
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/24
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/25
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/26
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/27
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/28
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/29
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/3
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/30
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/31
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/32
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/33
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/34
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/35
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/36
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/37
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/38
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/39
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/4
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/40
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/41
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/42
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/43
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/44
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/45
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/46
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/47
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/48
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/49
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/5
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/50
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/51
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/52
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/53
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/54
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/55
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/6
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/7
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/8
#
#
#
# InferredBugs/inferredbugs/java/commons-codec/9
#
#
#
# InferredBugs/inferredbugs/java/SSM
#
#
#
# InferredBugs/inferredbugs/java/SSM/1
#
#
#
# InferredBugs/inferredbugs/java/ShedLock
#
#
#
# InferredBugs/inferredbugs/java/ShedLock/1
#
#
#
# InferredBugs/inferredbugs/java/EMV-NFC-Paycard-Enrollment
#
#
#
# InferredBugs/inferredbugs/java/EMV-NFC-Paycard-Enrollment/1
#
#
#
# InferredBugs/inferredbugs/java/EMV-NFC-Paycard-Enrollment/2
#
#
#
# InferredBugs/inferredbugs/java/EMV-NFC-Paycard-Enrollment/3
#
#
#
# InferredBugs/inferredbugs/java/EMV-NFC-Paycard-Enrollment/4
#
#
#
# InferredBugs/inferredbugs/java/javassist
#
#
#
# InferredBugs/inferredbugs/java/javassist/1
#
#
#
# InferredBugs/inferredbugs/java/javassist/10
#
#
#
# InferredBugs/inferredbugs/java/javassist/11
#
#
#
# InferredBugs/inferredbugs/java/javassist/12
#
#
#
# InferredBugs/inferredbugs/java/javassist/13
#
#
#
# InferredBugs/inferredbugs/java/javassist/14
#
#
#
# InferredBugs/inferredbugs/java/javassist/15
#
#
#
# InferredBugs/inferredbugs/java/javassist/16
#
#
#
# InferredBugs/inferredbugs/java/javassist/2
#
#
#
# InferredBugs/inferredbugs/java/javassist/3
#
#
#
# InferredBugs/inferredbugs/java/javassist/4
#
#
#
# InferredBugs/inferredbugs/java/javassist/5
#
#
#
# InferredBugs/inferredbugs/java/javassist/6
#
#
#
# InferredBugs/inferredbugs/java/javassist/7
#
#
#
# InferredBugs/inferredbugs/java/javassist/8
#
#
#
# InferredBugs/inferredbugs/java/javassist/9
#
#
#
# InferredBugs/inferredbugs/java/github-plugin
#
#
#
# InferredBugs/inferredbugs/java/github-plugin/1
#
#
#
# InferredBugs/inferredbugs/java/github-plugin/10
#
#
#
# InferredBugs/inferredbugs/java/github-plugin/11
#
#
#
# InferredBugs/inferredbugs/java/github-plugin/12
#
#
#
# InferredBugs/inferredbugs/java/github-plugin/13
#
#
#
# InferredBugs/inferredbugs/java/github-plugin/14
#
#
#
# InferredBugs/inferredbugs/java/github-plugin/15
#
#
#
# InferredBugs/inferredbugs/java/github-plugin/16
#
#
#
# InferredBugs/inferredbugs/java/github-plugin/2
#
#
#
# InferredBugs/inferredbugs/java/github-plugin/3
#
#
#
# InferredBugs/inferredbugs/java/github-plugin/4
#
#
#
# InferredBugs/inferredbugs/java/github-plugin/5
#
#
#
# InferredBugs/inferredbugs/java/github-plugin/6
#
#
#
# InferredBugs/inferredbugs/java/github-plugin/7
#
#
#
# InferredBugs/inferredbugs/java/github-plugin/8
#
#
#
# InferredBugs/inferredbugs/java/github-plugin/9
#
#
#
# InferredBugs/inferredbugs/java/ha-bridge
#
#
#
# InferredBugs/inferredbugs/java/ha-bridge/1
#
#
#
# InferredBugs/inferredbugs/java/ha-bridge/10
#
#
#
# InferredBugs/inferredbugs/java/ha-bridge/2
#
#
#
# InferredBugs/inferredbugs/java/ha-bridge/3
#
#
#
# InferredBugs/inferredbugs/java/ha-bridge/4
#
#
#
# InferredBugs/inferredbugs/java/ha-bridge/5
#
#
#
# InferredBugs/inferredbugs/java/ha-bridge/6
#
#
#
# InferredBugs/inferredbugs/java/ha-bridge/7
#
#
#
# InferredBugs/inferredbugs/java/ha-bridge/8
#
#
#
# InferredBugs/inferredbugs/java/ha-bridge/9
#
#
#
# InferredBugs/inferredbugs/java/ysoserial
#
#
#
# InferredBugs/inferredbugs/java/ysoserial/1
#
#
#
# InferredBugs/inferredbugs/java/hierarchical-clustering-java
#
#
#
# InferredBugs/inferredbugs/java/hierarchical-clustering-java/1
#
#
#
# InferredBugs/inferredbugs/java/nzbhydra2
#
#
#
# InferredBugs/inferredbugs/java/nzbhydra2/1
#
#
#
# InferredBugs/inferredbugs/java/nzbhydra2/2
#
#
#
# InferredBugs/inferredbugs/java/nzbhydra2/3
#
#
#
# InferredBugs/inferredbugs/java/nzbhydra2/4
#
#
#
# InferredBugs/inferredbugs/java/nzbhydra2/5
#
#
#
# InferredBugs/inferredbugs/java/nzbhydra2/6
#
#
#
# InferredBugs/inferredbugs/java/nzbhydra2/7
#
#
#
# InferredBugs/inferredbugs/java/nzbhydra2/8
#
#
#
# InferredBugs/inferredbugs/java/nzbhydra2/9
#
#
#
# InferredBugs/inferredbugs/java/X-SpringBoot
#
#
#
# InferredBugs/inferredbugs/java/X-SpringBoot/1
#
#
#
# InferredBugs/inferredbugs/java/X-SpringBoot/2
#
#
#
# InferredBugs/inferredbugs/java/X-SpringBoot/3
#
#
#
# InferredBugs/inferredbugs/java/ByteTCC
#
#
#
# InferredBugs/inferredbugs/java/ByteTCC/1
#
#
#
# InferredBugs/inferredbugs/java/ByteTCC/2
#
#
#
# InferredBugs/inferredbugs/java/ByteTCC/3
#
#
#
# InferredBugs/inferredbugs/java/ByteTCC/4
#
#
#
# InferredBugs/inferredbugs/java/ByteTCC/5
#
#
#
# InferredBugs/inferredbugs/java/ByteTCC/6
#
#
#
# InferredBugs/inferredbugs/java/jeeves
#
#
#
# InferredBugs/inferredbugs/java/jeeves/1
#
#
#
# InferredBugs/inferredbugs/java/jeeves/2
#
#
#
# InferredBugs/inferredbugs/java/commons-pool
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/1
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/10
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/11
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/12
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/13
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/14
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/15
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/16
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/17
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/18
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/19
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/2
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/20
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/21
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/22
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/23
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/24
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/25
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/26
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/27
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/28
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/29
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/3
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/30
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/4
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/5
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/6
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/7
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/8
#
#
#
# InferredBugs/inferredbugs/java/commons-pool/9
#
#
#
# InferredBugs/inferredbugs/java/Sundial
#
#
#
# InferredBugs/inferredbugs/java/Sundial/1
#
#
#
# InferredBugs/inferredbugs/java/microservices-platform
#
#
#
# InferredBugs/inferredbugs/java/microservices-platform/1
#
#
#
# InferredBugs/inferredbugs/java/seyren
#
#
#
# InferredBugs/inferredbugs/java/seyren/1
#
#
#
# InferredBugs/inferredbugs/java/seyren/2
#
#
#
# InferredBugs/inferredbugs/java/MillionHero
#
#
#
# InferredBugs/inferredbugs/java/MillionHero/1
#
#
#
# InferredBugs/inferredbugs/java/MillionHero/2
#
#
#
# InferredBugs/inferredbugs/java/MillionHero/3
#
#
#
# InferredBugs/inferredbugs/java/MillionHero/4
#
#
#
# InferredBugs/inferredbugs/java/MillionHero/5
#
#
#
# InferredBugs/inferredbugs/java/MillionHero/6
#
#
#
# InferredBugs/inferredbugs/java/MillionHero/7
#
#
#
# InferredBugs/inferredbugs/java/firebase-admin-java
#
#
#
# InferredBugs/inferredbugs/java/firebase-admin-java/1
#
#
#
# InferredBugs/inferredbugs/java/firebase-admin-java/2
#
#
#
# InferredBugs/inferredbugs/java/firebase-admin-java/3
#
#
#
# InferredBugs/inferredbugs/java/firebase-admin-java/4
#
#
#
# InferredBugs/inferredbugs/java/firebase-admin-java/5
#
#
#
# InferredBugs/inferredbugs/java/firebase-admin-java/6
#
#
#
# InferredBugs/inferredbugs/java/firebase-admin-java/7
#
#
#
# InferredBugs/inferredbugs/java/firebase-admin-java/8
#
#
#
# InferredBugs/inferredbugs/java/hmily
#
#
#
# InferredBugs/inferredbugs/java/hmily/1
#
#
#
# InferredBugs/inferredbugs/java/hmily/2
#
#
#
# InferredBugs/inferredbugs/java/httpclientutil
#
#
#
# InferredBugs/inferredbugs/java/httpclientutil/1
#
#
#
# InferredBugs/inferredbugs/java/httpclientutil/2
#
#
#
# InferredBugs/inferredbugs/java/httpclientutil/3
#
#
#
# InferredBugs/inferredbugs/java/httpclientutil/4
#
#
#
# InferredBugs/inferredbugs/java/unipop
#
#
#
# InferredBugs/inferredbugs/java/unipop/1
#
#
#
# InferredBugs/inferredbugs/java/unipop/2
#
#
#
# InferredBugs/inferredbugs/java/SpringCloud
#
#
#
# InferredBugs/inferredbugs/java/SpringCloud/1
#
#
#
# InferredBugs/inferredbugs/java/hipster
#
#
#
# InferredBugs/inferredbugs/java/hipster/1
#
#
#
# InferredBugs/inferredbugs/java/hipster/2
#
#
#
# InferredBugs/inferredbugs/java/hipster/3
#
#
#
# InferredBugs/inferredbugs/java/hipster/4
#
#
#
# InferredBugs/inferredbugs/java/hipster/5
#
#
#
# InferredBugs/inferredbugs/java/boilerpipe
#
#
#
# InferredBugs/inferredbugs/java/boilerpipe/1
#
#
#
# InferredBugs/inferredbugs/java/boilerpipe/2
#
#
#
# InferredBugs/inferredbugs/java/boilerpipe/3
#
#
#
# InferredBugs/inferredbugs/java/helios
#
#
#
# InferredBugs/inferredbugs/java/helios/1
#
#
#
# InferredBugs/inferredbugs/java/helios/10
#
#
#
# InferredBugs/inferredbugs/java/helios/11
#
#
#
# InferredBugs/inferredbugs/java/helios/12
#
#
#
# InferredBugs/inferredbugs/java/helios/13
#
#
#
# InferredBugs/inferredbugs/java/helios/14
#
#
#
# InferredBugs/inferredbugs/java/helios/15
#
#
#
# InferredBugs/inferredbugs/java/helios/16
#
#
#
# InferredBugs/inferredbugs/java/helios/17
#
#
#
# InferredBugs/inferredbugs/java/helios/18
#
#
#
# InferredBugs/inferredbugs/java/helios/19
#
#
#
# InferredBugs/inferredbugs/java/helios/2
#
#
#
# InferredBugs/inferredbugs/java/helios/20
#
#
#
# InferredBugs/inferredbugs/java/helios/21
#
#
#
# InferredBugs/inferredbugs/java/helios/22
#
#
#
# InferredBugs/inferredbugs/java/helios/23
#
#
#
# InferredBugs/inferredbugs/java/helios/24
#
#
#
# InferredBugs/inferredbugs/java/helios/25
#
#
#
# InferredBugs/inferredbugs/java/helios/26
#
#
#
# InferredBugs/inferredbugs/java/helios/27
#
#
#
# InferredBugs/inferredbugs/java/helios/28
#
#
#
# InferredBugs/inferredbugs/java/helios/29
#
#
#
# InferredBugs/inferredbugs/java/helios/3
#
#
#
# InferredBugs/inferredbugs/java/helios/30
#
#
#
# InferredBugs/inferredbugs/java/helios/31
#
#
#
# InferredBugs/inferredbugs/java/helios/32
#
#
#
# InferredBugs/inferredbugs/java/helios/33
#
#
#
# InferredBugs/inferredbugs/java/helios/34
#
#
#
# InferredBugs/inferredbugs/java/helios/4
#
#
#
# InferredBugs/inferredbugs/java/helios/5
#
#
#
# InferredBugs/inferredbugs/java/helios/6
#
#
#
# InferredBugs/inferredbugs/java/helios/7
#
#
#
# InferredBugs/inferredbugs/java/helios/8
#
#
#
# InferredBugs/inferredbugs/java/helios/9
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/1
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/10
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/11
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/12
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/13
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/14
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/15
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/16
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/17
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/18
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/19
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/2
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/20
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/21
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/22
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/23
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/24
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/25
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/26
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/27
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/28
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/29
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/3
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/30
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/31
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/32
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/4
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/5
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/6
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/7
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/8
#
#
#
# InferredBugs/inferredbugs/java/kiftd-source/9
#
#
#
# InferredBugs/inferredbugs/java/commons-compress
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/1
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/10
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/11
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/12
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/13
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/14
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/15
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/16
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/17
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/18
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/19
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/2
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/20
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/21
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/22
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/23
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/24
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/25
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/26
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/27
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/28
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/29
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/3
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/30
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/31
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/32
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/33
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/34
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/35
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/36
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/37
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/38
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/39
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/4
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/40
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/41
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/42
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/5
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/6
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/7
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/8
#
#
#
# InferredBugs/inferredbugs/java/commons-compress/9
#
#
#
# InferredBugs/inferredbugs/java/config-toolkit
#
#
#
# InferredBugs/inferredbugs/java/config-toolkit/1
#
#
#
# InferredBugs/inferredbugs/java/config-toolkit/2
#
#
#
# InferredBugs/inferredbugs/java/config-toolkit/3
#
#
#
# InferredBugs/inferredbugs/java/config-toolkit/4
#
#
#
# InferredBugs/inferredbugs/java/omid
#
#
#
# InferredBugs/inferredbugs/java/omid/1
#
#
#
# InferredBugs/inferredbugs/java/omid/10
#
#
#
# InferredBugs/inferredbugs/java/omid/11
#
#
#
# InferredBugs/inferredbugs/java/omid/12
#
#
#
# InferredBugs/inferredbugs/java/omid/13
#
#
#
# InferredBugs/inferredbugs/java/omid/14
#
#
#
# InferredBugs/inferredbugs/java/omid/15
#
#
#
# InferredBugs/inferredbugs/java/omid/16
#
#
#
# InferredBugs/inferredbugs/java/omid/17
#
#
#
# InferredBugs/inferredbugs/java/omid/18
#
#
#
# InferredBugs/inferredbugs/java/omid/19
#
#
#
# InferredBugs/inferredbugs/java/omid/2
#
#
#
# InferredBugs/inferredbugs/java/omid/20
#
#
#
# InferredBugs/inferredbugs/java/omid/21
#
#
#
# InferredBugs/inferredbugs/java/omid/22
#
#
#
# InferredBugs/inferredbugs/java/omid/23
#
#
#
# InferredBugs/inferredbugs/java/omid/24
#
#
#
# InferredBugs/inferredbugs/java/omid/25
#
#
#
# InferredBugs/inferredbugs/java/omid/3
#
#
#
# InferredBugs/inferredbugs/java/omid/4
#
#
#
# InferredBugs/inferredbugs/java/omid/5
#
#
#
# InferredBugs/inferredbugs/java/omid/6
#
#
#
# InferredBugs/inferredbugs/java/omid/7
#
#
#
# InferredBugs/inferredbugs/java/omid/8
#
#
#
# InferredBugs/inferredbugs/java/omid/9
#
#
#
# InferredBugs/inferredbugs/java/wsc
#
#
#
# InferredBugs/inferredbugs/java/wsc/1
#
#
#
# InferredBugs/inferredbugs/java/wsc/2
#
#
#
# InferredBugs/inferredbugs/java/wsc/3
#
#
#
# InferredBugs/inferredbugs/java/wsc/4
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/1
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/10
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/11
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/12
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/13
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/14
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/15
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/16
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/17
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/18
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/19
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/2
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/20
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/21
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/22
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/23
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/24
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/25
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/26
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/3
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/4
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/5
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/6
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/7
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/8
#
#
#
# InferredBugs/inferredbugs/java/fabric8-maven-plugin/9
#
#
#
# InferredBugs/inferredbugs/java/arthas
#
#
#
# InferredBugs/inferredbugs/java/arthas/1
#
#
#
# InferredBugs/inferredbugs/java/arthas/2
#
#
#
# InferredBugs/inferredbugs/java/arthas/3
#
#
#
# InferredBugs/inferredbugs/java/arthas/4
#
#
#
# InferredBugs/inferredbugs/java/arthas/5
#
#
#
# InferredBugs/inferredbugs/java/arthas/6
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/1
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/10
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/11
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/12
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/13
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/14
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/15
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/16
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/17
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/18
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/19
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/2
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/20
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/21
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/22
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/3
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/4
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/5
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/6
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/7
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/8
#
#
#
# InferredBugs/inferredbugs/java/jackson-databind/9
#
#
#
# InferredBugs/inferredbugs/java/migrations
#
#
#
# InferredBugs/inferredbugs/java/migrations/1
#
#
#
# InferredBugs/inferredbugs/java/migrations/2
#
#
#
# InferredBugs/inferredbugs/java/migrations/3
#
#
#
# InferredBugs/inferredbugs/java/migrations/4
#
#
#
# InferredBugs/inferredbugs/java/migrations/5
#
#
#
# InferredBugs/inferredbugs/java/scoold
#
#
#
# InferredBugs/inferredbugs/java/scoold/1
#
#
#
# InferredBugs/inferredbugs/java/EasyCaptcha
#
#
#
# InferredBugs/inferredbugs/java/EasyCaptcha/1
#
#
#
# InferredBugs/inferredbugs/java/EasyCaptcha/2
#
#
#
# InferredBugs/inferredbugs/java/EasyCaptcha/3
#
#
#
# InferredBugs/inferredbugs/java/EasyCaptcha/4
#
#
#
# InferredBugs/inferredbugs/java/springside4
#
#
#
# InferredBugs/inferredbugs/java/springside4/1
#
#
#
# InferredBugs/inferredbugs/java/springside4/10
#
#
#
# InferredBugs/inferredbugs/java/springside4/11
#
#
#
# InferredBugs/inferredbugs/java/springside4/12
#
#
#
# InferredBugs/inferredbugs/java/springside4/13
#
#
#
# InferredBugs/inferredbugs/java/springside4/2
#
#
#
# InferredBugs/inferredbugs/java/springside4/3
#
#
#
# InferredBugs/inferredbugs/java/springside4/4
#
#
#
# InferredBugs/inferredbugs/java/springside4/5
#
#
#
# InferredBugs/inferredbugs/java/springside4/6
#
#
#
# InferredBugs/inferredbugs/java/springside4/7
#
#
#
# InferredBugs/inferredbugs/java/springside4/8
#
#
#
# InferredBugs/inferredbugs/java/springside4/9
#
#
#
# InferredBugs/inferredbugs/java/vaadin4spring
#
#
#
# InferredBugs/inferredbugs/java/vaadin4spring/1
#
#
#
# InferredBugs/inferredbugs/java/spring-cloud-zuul-ratelimit
#
#
#
# InferredBugs/inferredbugs/java/spring-cloud-zuul-ratelimit/1
#
#
#
# InferredBugs/inferredbugs/java/spring-cloud-zuul-ratelimit/2
#
#
#
# InferredBugs/inferredbugs/java/spring-cloud-zuul-ratelimit/3
#
#
#
# InferredBugs/inferredbugs/java/spring-cloud-zuul-ratelimit/4
#
#
#
# InferredBugs/inferredbugs/java/J2V8
#
#
#
# InferredBugs/inferredbugs/java/J2V8/1
#
#
#
# InferredBugs/inferredbugs/java/J2V8/10
#
#
#
# InferredBugs/inferredbugs/java/J2V8/11
#
#
#
# InferredBugs/inferredbugs/java/J2V8/12
#
#
#
# InferredBugs/inferredbugs/java/J2V8/13
#
#
#
# InferredBugs/inferredbugs/java/J2V8/14
#
#
#
# InferredBugs/inferredbugs/java/J2V8/15
#
#
#
# InferredBugs/inferredbugs/java/J2V8/2
#
#
#
# InferredBugs/inferredbugs/java/J2V8/3
#
#
#
# InferredBugs/inferredbugs/java/J2V8/4
#
#
#
# InferredBugs/inferredbugs/java/J2V8/5
#
#
#
# InferredBugs/inferredbugs/java/J2V8/6
#
#
#
# InferredBugs/inferredbugs/java/J2V8/7
#
#
#
# InferredBugs/inferredbugs/java/J2V8/8
#
#
#
# InferredBugs/inferredbugs/java/J2V8/9
#
#
#
# InferredBugs/inferredbugs/java/Oak
#
#
#
# InferredBugs/inferredbugs/java/Oak/1
#
#
#
# InferredBugs/inferredbugs/java/Oak/2
#
#
#
# InferredBugs/inferredbugs/java/Oak/3
#
#
#
# InferredBugs/inferredbugs/java/Oak/4
#
#
#
# InferredBugs/inferredbugs/java/Oak/5
#
#
#
# InferredBugs/inferredbugs/java/Oak/6
#
#
#
# InferredBugs/inferredbugs/java/Oak/7
#
#
#
# InferredBugs/inferredbugs/java/EasyReport
#
#
#
# InferredBugs/inferredbugs/java/EasyReport/1
#
#
#
# InferredBugs/inferredbugs/java/dataverse
#
#
#
# InferredBugs/inferredbugs/java/dataverse/1
#
#
#
# InferredBugs/inferredbugs/java/dataverse/10
#
#
#
# InferredBugs/inferredbugs/java/dataverse/11
#
#
#
# InferredBugs/inferredbugs/java/dataverse/12
#
#
#
# InferredBugs/inferredbugs/java/dataverse/13
#
#
#
# InferredBugs/inferredbugs/java/dataverse/14
#
#
#
# InferredBugs/inferredbugs/java/dataverse/15
#
#
#
# InferredBugs/inferredbugs/java/dataverse/16
#
#
#
# InferredBugs/inferredbugs/java/dataverse/17
#
#
#
# InferredBugs/inferredbugs/java/dataverse/18
#
#
#
# InferredBugs/inferredbugs/java/dataverse/19
#
#
#
# InferredBugs/inferredbugs/java/dataverse/2
#
#
#
# InferredBugs/inferredbugs/java/dataverse/20
#
#
#
# InferredBugs/inferredbugs/java/dataverse/21
#
#
#
# InferredBugs/inferredbugs/java/dataverse/22
#
#
#
# InferredBugs/inferredbugs/java/dataverse/23
#
#
#
# InferredBugs/inferredbugs/java/dataverse/24
#
#
#
# InferredBugs/inferredbugs/java/dataverse/3
#
#
#
# InferredBugs/inferredbugs/java/dataverse/4
#
#
#
# InferredBugs/inferredbugs/java/dataverse/5
#
#
#
# InferredBugs/inferredbugs/java/dataverse/6
#
#
#
# InferredBugs/inferredbugs/java/dataverse/7
#
#
#
# InferredBugs/inferredbugs/java/dataverse/8
#
#
#
# InferredBugs/inferredbugs/java/dataverse/9
#
#
#
# InferredBugs/inferredbugs/java/ojAlgo
#
#
#
# InferredBugs/inferredbugs/java/ojAlgo/1
#
#
#
# InferredBugs/inferredbugs/java/ojAlgo/10
#
#
#
# InferredBugs/inferredbugs/java/ojAlgo/11
#
#
#
# InferredBugs/inferredbugs/java/ojAlgo/12
#
#
#
# InferredBugs/inferredbugs/java/ojAlgo/13
#
#
#
# InferredBugs/inferredbugs/java/ojAlgo/14
#
#
#
# InferredBugs/inferredbugs/java/ojAlgo/15
#
#
#
# InferredBugs/inferredbugs/java/ojAlgo/16
#
#
#
# InferredBugs/inferredbugs/java/ojAlgo/17
#
#
#
# InferredBugs/inferredbugs/java/ojAlgo/2
#
#
#
# InferredBugs/inferredbugs/java/ojAlgo/3
#
#
#
# InferredBugs/inferredbugs/java/ojAlgo/4
#
#
#
# InferredBugs/inferredbugs/java/ojAlgo/5
#
#
#
# InferredBugs/inferredbugs/java/ojAlgo/6
#
#
#
# InferredBugs/inferredbugs/java/ojAlgo/7
#
#
#
# InferredBugs/inferredbugs/java/ojAlgo/8
#
#
#
# InferredBugs/inferredbugs/java/ojAlgo/9
#
#
#
# InferredBugs/inferredbugs/java/acs-aem-commons
#
#
#
# InferredBugs/inferredbugs/java/acs-aem-commons/1
#
#
#
# InferredBugs/inferredbugs/java/acs-aem-commons/10
#
#
#
# InferredBugs/inferredbugs/java/acs-aem-commons/11
#
#
#
# InferredBugs/inferredbugs/java/acs-aem-commons/12
#
#
#
# InferredBugs/inferredbugs/java/acs-aem-commons/13
#
#
#
# InferredBugs/inferredbugs/java/acs-aem-commons/14
#
#
#
# InferredBugs/inferredbugs/java/acs-aem-commons/15
#
#
#
# InferredBugs/inferredbugs/java/acs-aem-commons/16
#
#
#
# InferredBugs/inferredbugs/java/acs-aem-commons/17
#
#
#
# InferredBugs/inferredbugs/java/acs-aem-commons/2
#
#
#
# InferredBugs/inferredbugs/java/acs-aem-commons/3
#
#
#
# InferredBugs/inferredbugs/java/acs-aem-commons/4
#
#
#
# InferredBugs/inferredbugs/java/acs-aem-commons/5
#
#
#
# InferredBugs/inferredbugs/java/acs-aem-commons/6
#
#
#
# InferredBugs/inferredbugs/java/acs-aem-commons/7
#
#
#
# InferredBugs/inferredbugs/java/acs-aem-commons/8
#
#
#
# InferredBugs/inferredbugs/java/acs-aem-commons/9
#
#
#
# InferredBugs/inferredbugs/java/bistoury
#
#
#
# InferredBugs/inferredbugs/java/bistoury/1
#
#
#
# InferredBugs/inferredbugs/java/apgdiff
#
#
#
# InferredBugs/inferredbugs/java/apgdiff/1
#
#
#
# InferredBugs/inferredbugs/java/apgdiff/2
#
#
#
# InferredBugs/inferredbugs/java/apgdiff/3
#
#
#
# InferredBugs/inferredbugs/java/apgdiff/4
#
#
#
# InferredBugs/inferredbugs/java/apgdiff/5
#
#
#
# InferredBugs/inferredbugs/java/apgdiff/6
#
#
#
# InferredBugs/inferredbugs/java/apgdiff/7
#
#
#
# InferredBugs/inferredbugs/java/EasyFlow
#
#
#
# InferredBugs/inferredbugs/java/EasyFlow/1
#
#
#
# InferredBugs/inferredbugs/java/EasyFlow/2
#
#
#
# InferredBugs/inferredbugs/java/EasyFlow/3
#
#
#
# InferredBugs/inferredbugs/java/elasticsearch-suggest-plugin
#
#
#
# InferredBugs/inferredbugs/java/elasticsearch-suggest-plugin/1
#
#
#
# InferredBugs/inferredbugs/java/ohc
#
#
#
# InferredBugs/inferredbugs/java/ohc/1
#
#
#
# InferredBugs/inferredbugs/java/ohc/10
#
#
#
# InferredBugs/inferredbugs/java/ohc/11
#
#
#
# InferredBugs/inferredbugs/java/ohc/12
#
#
#
# ...
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/103
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/104
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/105
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/106
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/107
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/108
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/109
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/11
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/110
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/111
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/112
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/113
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/114
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/115
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/12
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/13
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/14
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/15
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/16
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/17
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/18
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/19
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/2
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/20
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/21
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/22
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/23
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/24
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/25
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/26
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/27
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/28
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/29
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/3
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/30
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/31
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/32
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/33
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/34
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/35
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/36
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/37
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/38
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/39
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/4
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/40
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/41
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/42
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/43
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/44
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/45
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/46
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/47
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/48
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/49
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/5
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/50
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/51
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/52
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/53
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/54
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/55
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/56
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/57
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/58
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/59
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/6
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/60
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/61
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/62
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/63
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/64
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/65
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/66
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/67
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/68
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/69
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/7
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/70
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/71
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/72
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/73
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/74
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/75
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/76
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/77
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/78
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/79
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/8
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/80
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/81
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/82
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/83
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/84
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/85
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/86
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/87
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/88
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/89
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/9
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/90
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/91
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/92
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/93
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/94
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/95
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/96
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/97
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/98
#
#
#
# InferredBugs/inferredbugs/java/rxjava2-jdbc/99
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/1
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/10
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/11
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/12
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/13
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/14
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/15
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/16
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/17
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/18
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/19
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/2
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/20
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/21
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/22
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/23
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/24
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/25
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/26
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/27
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/28
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/29
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/3
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/30
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/31
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/32
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/33
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/34
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/35
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/36
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/37
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/4
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/5
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/6
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/7
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/8
#
#
#
# InferredBugs/inferredbugs/java/cloud-slang/9
#
#
#
# InferredBugs/inferredbugs/java/knife
#
#
#
# InferredBugs/inferredbugs/java/knife/1
#
#
#
# InferredBugs/inferredbugs/java/knife/10
#
#
#
# InferredBugs/inferredbugs/java/knife/2
#
#
#
# InferredBugs/inferredbugs/java/knife/3
#
#
#
# InferredBugs/inferredbugs/java/knife/4
#
#
#
# InferredBugs/inferredbugs/java/knife/5
#
#
#
# InferredBugs/inferredbugs/java/knife/6
#
#
#
# InferredBugs/inferredbugs/java/knife/7
#
#
#
# InferredBugs/inferredbugs/java/knife/8
#
#
#
# InferredBugs/inferredbugs/java/knife/9
#
#
#
# InferredBugs/inferredbugs/java/disconf
#
#
#
# InferredBugs/inferredbugs/java/disconf/1
#
#
#
# InferredBugs/inferredbugs/java/disconf/2
#
#
#
# InferredBugs/inferredbugs/java/disconf/3
#
#
#
# InferredBugs/inferredbugs/java/disconf/4
#
#
#
# InferredBugs/inferredbugs/java/shiro
#
#
#
# InferredBugs/inferredbugs/java/shiro/1
#
#
#
# InferredBugs/inferredbugs/java/shiro/10
#
#
#
# InferredBugs/inferredbugs/java/shiro/11
#
#
#
# InferredBugs/inferredbugs/java/shiro/12
#
#
#
# InferredBugs/inferredbugs/java/shiro/13
#
#
#
# InferredBugs/inferredbugs/java/shiro/14
#
#
#
# InferredBugs/inferredbugs/java/shiro/15
#
#
#
# InferredBugs/inferredbugs/java/shiro/16
#
#
#
# InferredBugs/inferredbugs/java/shiro/17
#
#
#
# InferredBugs/inferredbugs/java/shiro/18
#
#
#
# InferredBugs/inferredbugs/java/shiro/19
#
#
#
# InferredBugs/inferredbugs/java/shiro/2
#
#
#
# InferredBugs/inferredbugs/java/shiro/3
#
#
#
# InferredBugs/inferredbugs/java/shiro/4
#
#
#
# InferredBugs/inferredbugs/java/shiro/5
#
#
#
# InferredBugs/inferredbugs/java/shiro/6
#
#
#
# InferredBugs/inferredbugs/java/shiro/7
#
#
#
# InferredBugs/inferredbugs/java/shiro/8
#
#
#
# InferredBugs/inferredbugs/java/shiro/9
#
#
#
# InferredBugs/inferredbugs/java/joss
#
#
#
# InferredBugs/inferredbugs/java/joss/1
#
#
#
# InferredBugs/inferredbugs/java/joss/10
#
#
#
# InferredBugs/inferredbugs/java/joss/11
#
#
#
# InferredBugs/inferredbugs/java/joss/12
#
#
#
# InferredBugs/inferredbugs/java/joss/13
#
#
#
# InferredBugs/inferredbugs/java/joss/14
#
#
#
# InferredBugs/inferredbugs/java/joss/15
#
#
#
# InferredBugs/inferredbugs/java/joss/16
#
#
#
# InferredBugs/inferredbugs/java/joss/17
#
#
#
# InferredBugs/inferredbugs/java/joss/18
#
#
#
# InferredBugs/inferredbugs/java/joss/19
#
#
#
# InferredBugs/inferredbugs/java/joss/2
#
#
#
# InferredBugs/inferredbugs/java/joss/20
#
#
#
# InferredBugs/inferredbugs/java/joss/21
#
#
#
# InferredBugs/inferredbugs/java/joss/22
#
#
#
# InferredBugs/inferredbugs/java/joss/23
#
#
#
# InferredBugs/inferredbugs/java/joss/24
#
#
#
# InferredBugs/inferredbugs/java/joss/25
#
#
#
# InferredBugs/inferredbugs/java/joss/26
#
#
#
# InferredBugs/inferredbugs/java/joss/27
#
#
#
# InferredBugs/inferredbugs/java/joss/28
#
#
#
# InferredBugs/inferredbugs/java/joss/29
#
#
#
# InferredBugs/inferredbugs/java/joss/3
#
#
#
# InferredBugs/inferredbugs/java/joss/30
#
#
#
# InferredBugs/inferredbugs/java/joss/31
#
#
#
# InferredBugs/inferredbugs/java/joss/32
#
#
#
# InferredBugs/inferredbugs/java/joss/33
#
#
#
# InferredBugs/inferredbugs/java/joss/34
#
#
#
# InferredBugs/inferredbugs/java/joss/35
#
#
#
# InferredBugs/inferredbugs/java/joss/36
#
#
#
# InferredBugs/inferredbugs/java/joss/37
#
#
#
# InferredBugs/inferredbugs/java/joss/38
#
#
#
# InferredBugs/inferredbugs/java/joss/39
#
#
#
# InferredBugs/inferredbugs/java/joss/4
#
#
#
# InferredBugs/inferredbugs/java/joss/40
#
#
#
# InferredBugs/inferredbugs/java/joss/41
#
#
#
# InferredBugs/inferredbugs/java/joss/5
#
#
#
# InferredBugs/inferredbugs/java/joss/6
#
#
#
# InferredBugs/inferredbugs/java/joss/7
#
#
#
# InferredBugs/inferredbugs/java/joss/8
#
#
#
# InferredBugs/inferredbugs/java/joss/9
#
#
#
# InferredBugs/inferredbugs/java/Thunder
#
#
#
# InferredBugs/inferredbugs/java/Thunder/1
#
#
#
# InferredBugs/inferredbugs/java/Thunder/2
#
#
#
# InferredBugs/inferredbugs/java/Thunder/3
#
#
#
# InferredBugs/inferredbugs/java/jenkinsfile-runner
#
#
#
# InferredBugs/inferredbugs/java/jenkinsfile-runner/1
#
#
#
# InferredBugs/inferredbugs/java/jenkinsfile-runner/2
#
#
#
# InferredBugs/inferredbugs/java/jenkinsfile-runner/3
#
#
#
# InferredBugs/inferredbugs/java/jenkinsfile-runner/4
#
#
#
# InferredBugs/inferredbugs/java/jenkinsfile-runner/5
#
#
#
# InferredBugs/inferredbugs/java/openstack4j
#
#
#
# InferredBugs/inferredbugs/java/openstack4j/1
#
#
#
# InferredBugs/inferredbugs/java/openstack4j/2
#
#
#
# InferredBugs/inferredbugs/java/openstack4j/3
#
#
#
# InferredBugs/inferredbugs/java/EDDI
#
#
#
# InferredBugs/inferredbugs/java/EDDI/1
#
#
#
# InferredBugs/inferredbugs/java/googleads-java-lib
#
#
#
# InferredBugs/inferredbugs/java/googleads-java-lib/1
#
#
#
# InferredBugs/inferredbugs/java/brpc-java
#
#
#
# InferredBugs/inferredbugs/java/brpc-java/1
#
#
#
# InferredBugs/inferredbugs/java/brpc-java/10
#
#
#
# InferredBugs/inferredbugs/java/brpc-java/2
#
#
#
# InferredBugs/inferredbugs/java/brpc-java/3
#
#
#
# InferredBugs/inferredbugs/java/brpc-java/4
#
#
#
# InferredBugs/inferredbugs/java/brpc-java/5
#
#
#
# InferredBugs/inferredbugs/java/brpc-java/6
#
#
#
# InferredBugs/inferredbugs/java/brpc-java/7
#
#
#
# InferredBugs/inferredbugs/java/brpc-java/8
#
#
#
# InferredBugs/inferredbugs/java/brpc-java/9
#
#
#
# InferredBugs/inferredbugs/java/itext7
#
#
#
# InferredBugs/inferredbugs/java/itext7/1
#
#
#
# InferredBugs/inferredbugs/java/itext7/10
#
#
#
# InferredBugs/inferredbugs/java/itext7/11
#
#
#
# InferredBugs/inferredbugs/java/itext7/12
#
#
#
# InferredBugs/inferredbugs/java/itext7/13
#
#
#
# InferredBugs/inferredbugs/java/itext7/14
#
#
#
# InferredBugs/inferredbugs/java/itext7/15
#
#
#
# InferredBugs/inferredbugs/java/itext7/16
#
#
#
# InferredBugs/inferredbugs/java/itext7/17
#
#
#
# InferredBugs/inferredbugs/java/itext7/18
#
#
#
# InferredBugs/inferredbugs/java/itext7/19
#
#
#
# InferredBugs/inferredbugs/java/itext7/2
#
#
#
# InferredBugs/inferredbugs/java/itext7/20
#
#
#
# InferredBugs/inferredbugs/java/itext7/21
#
#
#
# InferredBugs/inferredbugs/java/itext7/22
#
#
#
# InferredBugs/inferredbugs/java/itext7/23
#
#
#
# InferredBugs/inferredbugs/java/itext7/24
#
#
#
# InferredBugs/inferredbugs/java/itext7/25
#
#
#
# InferredBugs/inferredbugs/java/itext7/26
#
#
#
# InferredBugs/inferredbugs/java/itext7/27
#
#
#
# InferredBugs/inferredbugs/java/itext7/28
#
#
#
# InferredBugs/inferredbugs/java/itext7/29
#
#
#
# InferredBugs/inferredbugs/java/itext7/3
#
#
#
# InferredBugs/inferredbugs/java/itext7/30
#
#
#
# InferredBugs/inferredbugs/java/itext7/31
#
#
#
# InferredBugs/inferredbugs/java/itext7/32
#
#
#
# InferredBugs/inferredbugs/java/itext7/33
#
#
#
# InferredBugs/inferredbugs/java/itext7/34
#
#
#
# InferredBugs/inferredbugs/java/itext7/35
#
#
#
# InferredBugs/inferredbugs/java/itext7/36
#
#
#
# InferredBugs/inferredbugs/java/itext7/37
#
#
#
# InferredBugs/inferredbugs/java/itext7/38
#
#
#
# InferredBugs/inferredbugs/java/itext7/4
#
#
#
# InferredBugs/inferredbugs/java/itext7/5
#
#
#
# InferredBugs/inferredbugs/java/itext7/6
#
#
#
# InferredBugs/inferredbugs/java/itext7/7
#
#
#
# InferredBugs/inferredbugs/java/itext7/8
#
#
#
# InferredBugs/inferredbugs/java/itext7/9
#
#
#
# InferredBugs/inferredbugs/java/blade-tool
#
#
#
# InferredBugs/inferredbugs/java/blade-tool/1
#
#
#
# InferredBugs/inferredbugs/java/blade-tool/2
#
#
#
# InferredBugs/inferredbugs/java/blade-tool/3
#
#
#
# InferredBugs/inferredbugs/java/blade-tool/4
#
#
#
# InferredBugs/inferredbugs/java/blade-tool/5
#
#
#
# InferredBugs/inferredbugs/java/blade-tool/6
#
#
#
# InferredBugs/inferredbugs/java/jeromq
#
#
#
# InferredBugs/inferredbugs/java/jeromq/1
#
#
#
# InferredBugs/inferredbugs/java/jeromq/10
#
#
#
# InferredBugs/inferredbugs/java/jeromq/11
#
#
#
# InferredBugs/inferredbugs/java/jeromq/12
#
#
#
# InferredBugs/inferredbugs/java/jeromq/13
#
#
#
# InferredBugs/inferredbugs/java/jeromq/14
#
#
#
# InferredBugs/inferredbugs/java/jeromq/15
#
#
#
# InferredBugs/inferredbugs/java/jeromq/16
#
#
#
# InferredBugs/inferredbugs/java/jeromq/17
#
#
#
# InferredBugs/inferredbugs/java/jeromq/18
#
#
#
# InferredBugs/inferredbugs/java/jeromq/19
#
#
#
# InferredBugs/inferredbugs/java/jeromq/2
#
#
#
# InferredBugs/inferredbugs/java/jeromq/20
#
#
#
# InferredBugs/inferredbugs/java/jeromq/21
#
#
#
# InferredBugs/inferredbugs/java/jeromq/22
#
#
#
# InferredBugs/inferredbugs/java/jeromq/23
#
#
#
# InferredBugs/inferredbugs/java/jeromq/24
#
#
#
# InferredBugs/inferredbugs/java/jeromq/25
#
#
#
# InferredBugs/inferredbugs/java/jeromq/3
#
#
#
# InferredBugs/inferredbugs/java/jeromq/4
#
#
#
# InferredBugs/inferredbugs/java/jeromq/5
#
#
#
# InferredBugs/inferredbugs/java/jeromq/6
#
#
#
# InferredBugs/inferredbugs/java/jeromq/7
#
#
#
# InferredBugs/inferredbugs/java/jeromq/8
#
#
#
# InferredBugs/inferredbugs/java/jeromq/9
#
#
#
# InferredBugs/inferredbugs/java/validator-badge
#
#
#
# InferredBugs/inferredbugs/java/validator-badge/1
#
#
#
# InferredBugs/inferredbugs/java/RedisClient
#
#
#
# InferredBugs/inferredbugs/java/RedisClient/1
#
#
#
# InferredBugs/inferredbugs/java/RedisClient/2
#
#
#
# InferredBugs/inferredbugs/java/RedisClient/3
#
#
#
# InferredBugs/inferredbugs/java/RedisClient/4
#
#
#
# InferredBugs/inferredbugs/java/RedisClient/5
#
#
#
# InferredBugs/inferredbugs/java/kryonet
#
#
#
# InferredBugs/inferredbugs/java/kryonet/1
#
#
#
# InferredBugs/inferredbugs/java/spring-petclinic-microservices
#
#
#
# InferredBugs/inferredbugs/java/spring-petclinic-microservices/1
#
#
#
# InferredBugs/inferredbugs/java/selenium-jupiter
#
#
#
# InferredBugs/inferredbugs/java/selenium-jupiter/1
#
#
#
# InferredBugs/inferredbugs/java/selenium-jupiter/2
#
#
#
# InferredBugs/inferredbugs/java/selenium-jupiter/3

# %% [markdown]
# ## Analyze Bug Distribution

# %%
bug_type_dict = {}
for json in processed_data:
    bug_type_dict[json['BugInfo']['bug_type']] = bug_type_dict.get(json['BugInfo']['bug_type'], 0) + 1
for key in bug_type_dict:
    bug_type_dict[key] = round(bug_type_dict[key]/len(processed_data) * 100 ,2)

# %%
bug_type_dict
# Out:
# {'THREAD_SAFETY_VIOLATION': 22.74,
#  'RESOURCE_LEAK': 34.95,
#  'NULL_DEREFERENCE': 40.24,
#  'CHECKERS_PRINTF_ARGS': 0.96,
#  'CHECKERS_IMMUTABLE_CAST': 0.2,
#  'INTERFACE_NOT_THREAD_SAFE': 0.8,
#  'UNSAFE_GUARDED_BY_ACCESS': 0.11}

# %%
data = {'THREAD_SAFETY_VIOLATION': 22.74,
        'RESOURCE_LEAK': 34.95,
        'NULL_DEREFERENCE': 40.24,
        'CHECKERS_PRINTF_ARGS': 0.96,
        'CHECKERS_IMMUTABLE_CAST': 0.2,
        'INTERFACE_NOT_THREAD_SAFE': 0.8,
        'UNSAFE_GUARDED_BY_ACCESS': 0.11}

df = pd.DataFrame(list(data.items()), columns=['Bug Type', 'Percentage Count'])

df = df.sort_values(by='Percentage Count', ascending=False)

chart = alt.Chart(df).mark_bar().encode(
    x=alt.X('Percentage Count', axis=alt.Axis(title='Percentage Count')),
    y=alt.Y('Bug Type', axis=alt.Axis(title='Bug Type',), sort='-x'),
    tooltip=['Bug Type', 'Percentage Count'] 
).properties(
    title='Distribution of Bug Types in InferredBugs JAVA Subset',
    width = 600,
    height = 400
).interactive()

# Add text labels to the chart
text = chart.mark_text(
    align='left',
    baseline='middle',
    dx=5
).encode(
    text=alt.Text('Percentage Count', format='.2f')  # Format the text to 2 decimal places
)

final_chart = chart + text

final_chart = final_chart.configure_axis(
    grid=True
).configure_mark(
    color='lightblue'
).configure_view(
    strokeWidth=0
).configure(
    background='white'
)

final_chart.save('bug_type_distribution_bar_chart.json')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning:
#
# the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.

# %%
final_chart
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning:
#
# the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
# alt.LayerChart(...)

# %% [markdown]
# ## Extract Bug And Prepare Data For SFT And ORPO

# %%
def tokenize_code(code: str):
    return re.findall(r'\w+|[^\s\w]', code)

def map_tokens_to_lines(code):
    lines = code.splitlines()
    token_to_line = {}
    token_idx = 0
    for line_num, line in enumerate(lines):
        tokens = tokenize_code(line)
        for token in tokens:
            token_to_line[token_idx] = (line_num, line.strip())
            token_idx += 1
    return token_to_line

def extract_localized_bug_from_tokens(buggy_code: str, fixed_code: str):
    tokens_buggy = tokenize_code(buggy_code)
    tokens_fixed = tokenize_code(fixed_code)
    
    matcher = difflib.SequenceMatcher(None, tokens_buggy, tokens_fixed)
    token_map = map_tokens_to_lines(buggy_code)

    changed_lines = set()
    for tag, i1, i2, j1, j2 in matcher.get_opcodes():
        if tag in ("replace", "delete"):
            for token_idx in range(i1, i2):
                line_num, line_text = token_map.get(token_idx, (None, None))
                if line_num is not None:
                    changed_lines.add((line_num, line_text))

    sorted_lines = sorted(list(changed_lines), key=lambda x: x[0])
    localized_lines = [line for _, line in sorted_lines]
    return '\n'.join(localized_lines)

def generate_alpaca_prompt_orpo(buggy_code, fixed_code, patch):
    prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request, do not provide explanations just the answer

    ### Instruction:
    You are an expert JAVA coder. Given an input buggy method code written in JAVA, information about the bug, and the part of the code containing the probably bug (localized code containing bug), your task is to
    analyse the inputs and fix the buggy method and return the fixed method in JAVA. Only return the fixed code, no further explanation required.
    
    ### Input:
    #### JAVA Method containing bug:
    {}
    
    #### Bug Information:
    {}
    
    #### Localized Part of the Code Containing Bug:
    {}
    
    ### Response:"""

    prompt = prompt.format(buggy_code, fixed_code, patch)
    return prompt


def get_orpo_data(json_list):
    for entry in json_list:
        buggy_code = entry.get("BuggyCode", "")
        fixed_code = entry.get("FixedCode", "")
        bug_info = entry.get("BugInfo", "")
        patch = extract_localized_bug_from_tokens(buggy_code, fixed_code)
        # patch_fix = get_structured_patch(buggy_code, fixed_code)
        

        prompt = generate_alpaca_prompt_orpo(buggy_code, bug_info, patch)
        entry['prompt'] = prompt
        entry['chosen'] = fixed_code
        entry['rejected'] = buggy_code
        entry["LocalizedBug"] = patch
        entry['LocalizedPatchLength'] = len(patch)
        entry['CodeLength'] = len(buggy_code)
        # entry["PatchFix"] = patch_fix
    return json_list

# %%
orpo_dataset_inferredbugs = get_orpo_data(processed_data)

# %% [markdown]
# ## Data Filtering

# %%
import re
non_english_pattern = re.compile(r'[^\x00-\x7F]+')

def is_english_java_code(example):
    buggy_code = example.get("BuggyCode", "")
    return not non_english_pattern.search(buggy_code)
filtered_data = [ex for ex in orpo_dataset_inferredbugs if is_english_java_code(ex)]
len(filtered_data)
# Out:
# 7969

# %%
filtered_localized_data = []
for entry in filtered_data:
    if (entry['LocalizedPatchLength'] < 300 and entry['LocalizedPatchLength'] > 0) and (entry['CodeLength'] < 1200):
        filtered_localized_data.append(entry)

# %%
len(filtered_localized_data)
# Out:
# 3422

# %% [markdown]
# ## Save The Final Data

# %%
def dump_file_for_localization(data_list, output_file):
    keys_to_keep = ["BuggyCode", "BugInfo", "LocalizedBug", "LocalizedPatchLength", "FixedCode"]
    with open(output_file, "w", encoding="utf-8") as f:
        for item in data_list:
            filtered_item = {key: item[key] for key in keys_to_keep if key in item}
            f.write(json.dumps(filtered_item) + "\n")

# %%
import random
import json

data = filtered_localized_data

random.seed(42)
training_data = random.sample(data, 3000)

remaining_data = [item for item in data if item not in training_data]

test_data = random.sample(remaining_data, 300)

dump_file_for_localization(training_data, "InferredBugs_SFT_Train_with_bug_localization_it3.jsonl")
dump_file_for_localization(test_data, "InferredBugs_SFT_Test_with_bug_localization_it3.jsonl")


with open("InferredBugs_ORPO_Train_with_bug_localization.jsonl", "w") as train_file:
    for item in training_data:
        json.dump(item, train_file)
        train_file.write("\n")

with open("InferredBugs_ORPO_Test_with_bug_localization.jsonl", "w") as test_file:
    for item in test_data:
        json.dump(item, test_file)
        test_file.write("\n")

print("Training and test data successfully saved.")
# Out:
# Training and test data successfully saved.
